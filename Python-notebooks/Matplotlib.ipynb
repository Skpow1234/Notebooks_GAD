# %% [markdown]
# ### Topic Covered: Matplotlib

# %% [markdown]
# Write a program to visualize Company Sales Data & perform the following task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Datasets/company_sales_data.csv")

# %% [markdown]
# 1. Read Total profit of all months and show it using a line plot

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
plt.plot(df['total_profit'],marker='o',)
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# 2. Get total profit of all months and show line plot with the following Style properties.
# Generated line plot must include following Style properties: –
#
#     -Line Style dotted and Line-color should be red
#
#     -Show legend at the lower right location.
#
#     -X label name = Month Number
#
#     -Y label name = Sold unit’s number
#
#     -Add a circle marker.
#
#     -Line marker color as red
#
#     -Line width should be 3

# %%
plt.plot(df['total_units'],marker='o',mec='red',linewidth='3',linestyle = 'dotted',color='red')
plt.xlabel("Month Number",position='right')
plt.ylabel("Sold unit’s number")
# Out:
# Text(0, 0.5, 'Sold unit’s number')

# %% [markdown]
# 3. Read all product sales data and show it using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).

# %%
x1 = df['month_number']
y1 = df['facecream']
x2 = df['month_number']
y2 = df['facewash']
x3 = df['month_number']
y3 = df['toothpaste']
x4 = df['month_number']
y4 = df['bathingsoap']
x5 = df['month_number']
y5 = df['shampoo']

plt.plot(x1, y1,label='Face cream')
plt.plot(x2, y2,label='Face wash')
plt.plot(x3, y3,label='Toothpaste')
plt.plot(x4, y4,label='Bathing soap')
plt.plot(x5, y5,label='Shampoo')
plt.legend()
plt.xlabel("Month Number",position='right')
plt.ylabel("Sold unit’s number")
plt.show()

# %% [markdown]
# 4. Read toothpaste sales data of each month and show it using a scatter plot.

# %%
x = df['month_number']
y = df['toothpaste']
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel("Month Number",position='right')
plt.ylabel("Sold unit’s number")
plt.show()

# %% [markdown]
# 5. Read face cream and facewash product sales data and show it using the bar chart.

# %%
x = df['month_number']
y = df['facecream']
z = df['facewash']
X_axis = np.arange(len(x))

plt.bar(X_axis - 0.2, y, 0.4, label = 'Face Cream',color='#8B8878')
plt.bar(X_axis + 0.2, z, 0.4, label = 'Facewash',color='#CDC8B1')
  
plt.xticks(X_axis, x)
plt.xlabel("Month Number")
plt.ylabel("Sold unit’s number")

plt.legend()
plt.show()

# %% [markdown]
# 6.  Read sales data of bathing soap of all months and show it using a bar chart. Save this plot

# %%
x = df['month_number']
y = df['bathingsoap']

plt.bar(x, y, width=0.5 )
plt.title("Face Cream Product sales data", fontsize=15)
plt.xlabel("Month number")
plt.ylabel("Sold units")
plt.show()

# %% [markdown]
# 7. Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
x = df['total_profit']
plt.figure(facecolor='#6E7B8B')
plt.hist(x)
plt.show()

# %% [markdown]
# 8. Calculate total sale data for last year for each product and show it using a Pie chart as well as 3D pie chart

# %%
array=[df['facecream'].sum(axis=0),df['facewash'].sum(axis=0),df['toothpaste'].sum(axis=0),df['bathingsoap'].sum(axis=0),df['shampoo'].sum(axis=0),df['moisturizer'].sum(axis=0)]
mylabels = ["facecream","facewash",	"toothpaste","bathingsoap","shampoo","moisturizer"]
myexplode = [0, 0, 0, 0.25,0,0]
plt.figure(facecolor='#6E7B8B')
plt.pie(array, labels = mylabels,explode = myexplode,autopct='%1.1f%%', shadow=True)
plt.show()

# %% [markdown]
# 9. Read Bathing soap facewash of all months and display it using the Subplot

# %%
#plot 1:
x = df['month_number']
y = df['bathingsoap']

plt.subplot(2, 1, 1) # (R,C,No.)
plt.plot(x,y, color='r')
plt.title("Bathing soap sales",color='blue')
plt.xlabel("Month Number",position='right')
plt.ylabel("Sold unit’s number")    

#plot 2:
x = df['month_number']
y = df['facewash']
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.title("facewash sales",color='blue')
plt.xlabel("Month Number",position='right')
plt.ylabel("Sold unit’s number")    
plt.subplots_adjust(
                    wspace=0.4, 
                    hspace=1.2)

plt.show()

# %% [markdown]
# 10. Read all product sales data and show it using the stack plot.

# %%
import matplotlib.pyplot as plt
x = df['month_number']
y1 = df['facecream'],
y2 = df['facewash']
y3 = df['toothpaste']
y4 = df['bathingsoap']
y5 = df['shampoo']
y6 = df['moisturizer']

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3,y4,y5,y6)
plt.show()

# %% [markdown]
# ### Extra Questions:
# 1. Plot Simple bar chart showing popularity of Programming Languages.
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
# Popularity = [56, 39, 34, 34, 29]
# Security = [44 ,36 ,55, 50, 42]
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
x =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
y = [56, 39, 34, 34, 29]

plt.bar(x, y, width=0.5 ,color='#8B3A62',label='Programming Languages')

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("Popularity of major Programming Languages")
plt.legend()

# %%
x =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
y = [56, 39, 34, 34, 29]
z= [44 ,36 ,55, 50, 42]
  
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, y, 0.4, label = 'Popularity',color='#282828')
plt.bar(X_axis + 0.2, z, 0.4, label = 'Security',color='#515151')
  
plt.xticks(X_axis, x)
plt.xlabel("Languages")
plt.ylabel("Percentage")
plt.title("Popularity and Security of major Programming Languages")
plt.legend()
plt.show()

# %% [markdown]
# 2.  Plot Histogram, we have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
# Histogram showing Below Average, Average and Excellent distribution
# 40-60: Below Average
# 60-80: Average
# 80-100: Excellent

# %%
x = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]

plt.hist(x)      
plt.hist(x,color='#000000')

plt.show()

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
below_avg = Marks[np.logical_and(Marks >= 40, Marks < 60)]
avg_marks = Marks[np.logical_and(Marks >= 60, Marks < 80)]
exe_marks = Marks[np.logical_and(Marks >= 80, Marks <= 100)]

plt.hist(Marks)
# plt.hist(below_avg,color='black')
# plt.hist(avg_marks,color='red')
# plt.hist(exe_marks,color='green')
plt.show()
print('Below Average Students Are : ',below_avg.size)
print('Average Students Are : ',avg_marks.size)
print('Execelent Students Are : ',exe_marks.size)
# Out:
# Below Average Students Are :  5
# Average Students Are :  8
# Execelent Students Are :  4

# %% [markdown]
# To make your histogram look more appealing you cane use the following libraries

# %%
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
fig, axs = plt.subplots(1, 1,figsize =(10, 7),tight_layout = True)
N, bins, patches=axs.hist(marks,bins=[40,60,80,100])
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)
axs.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
rects = axs.patches
labels = ['Below Average', 'Average', 'Excellent'] 
for rect, label in zip(rects, labels):
    height = rect.get_height()
    axs.text(rect.get_x() + rect.get_width() / 2, height+0.01, label,
            ha='center', va='bottom')
# Out:
# C:\Users\prith\AppData\Local\Temp\ipykernel_21892\3058556980.py:12: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   axs.grid(b = True, color ='grey',

# %% [markdown]
# 3.  Titanic Data Set Download Data
#  Load the data file
#  (i) Create a pie chart presenting the male/female proportion
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
df = pd.read_csv('Datasets/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x = df.Sex.value_counts()
x
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
plt.pie(x, autopct='%.0f%%')
plt.legend(['Male','Female'])
plt.title('Male And Female Proportion')
plt.show()

# %%
plt.scatter(df[df['Sex']=='male'].Fare, df[df['Sex']=='male'].Age, label = 'Male', marker = '*',color='black')
plt.scatter(df[df['Sex']=='female'].Fare, df[df['Sex']=='female'].Age, label = 'Female', marker = '*',color='grey')
plt.legend()

plt.xlabel('Fare')
plt.ylabel('Age')

plt.grid()

plt.show()

# %% [markdown]
# ## Exercise 4
# Create a figure of size 15x8 with two subplots, top and bottom.
# Draw two lines in the top axes, one green and one orange.
# Add a legend for the top plot, Green and Orange. Put this legend in the top-middle of graph.
# Extra Challenge: In the bottom axes, create a graph of only the data points, marked by circles, but with no line connecting the points.
# Dataset for the exercise
# Take 3 columns a, b, c having values that are randomly generated between the range of (0 to 100).

# %%
a=np.random.randint(0,100,15)
b=np.random.randint(0,100,15)
c=np.random.randint(0,100,15)

print('\n',a,'\n',b,'\n',c,'\n')
# Out:
#  [85  1 74 14 72 46 82 59 62 11 72 33 94 85 16]
#  [30 36 39 14 26 39 72 10 14 57 37 90 79 39  3]
#  [10 88 96 88 49 27 60 66 67 43 59 98 71 65 93]

# %%
plt.figure(figsize=(15,8))

plt.subplot(2, 1, 1)
plt.plot(a,color='green',label='a')
plt.plot(b,color='orange',label='b')
plt.grid()
plt.legend(bbox_to_anchor=(0.52, 1.0))
plt.show()

plt.figure(figsize=(15,8))
plt.subplot(2, 1, 1)
plt.scatter(a,c,color='blue')
plt.scatter(b,c,color='blue')

plt.grid()
plt.show()

# %% [markdown]
# ### Exercise 5
# Create a figure with three subplots, aligned vertically.
# Create a bar graph for a and b on the first two, but at the last one draw both a and b, but put b on top of a! (Hint: use the bottom argument in the bar function)
# Make sure the color for a and b are consistent in all the subplots!
# Extra Challenge: Write the magnitude of each bar on top of it

# %%
x=np.random.randint(0,100,5)
y=np.random.randint(0,100,5)
z=np.random.randint(0,100,5)
print('\n',x,'\n',y,'\n',z,'\n')
# Out:
#  [38 29  2 49 22]
#  [80 87 96 12 93]
#  [28 85 60 18 56]

# %%
plt.figure(figsize=(10,10))
#plot 1:
plt.subplot(3, 1, 1) # (R,C,No.)
plt.bar(x,z,color='r')

#plot 2:

plt.subplot(3, 1, 2)
plt.bar(y,z)

#plot 3:
plt.subplot(3, 1, 3)
X_axis = np.arange(len(z))
  
plt.bar(X_axis - 0.2, x, 0.4, label = 'a',color='#282828')
plt.bar(X_axis + 0.2, y, 0.4, label = 'b',color='#515151')
  
plt.xticks(X_axis, z)
plt.show()

# %% [markdown]
# ### Exercise 6
# Visualize the mock data given below.
# Create bars to represent the turnover for each market.
# Use labels to make sure your audience understands the graph.
# Extra Challenge: On the opposite axis, draw a line to show each market share. (Hint: use ax.twinx())

# %%
boardid=['Day','Day_x','TSE','DAY_U']
turnover=[210652396,399764591,405868288,925231285]
turnover_si=[210,399,405,925]
marketshare= [10.8,20.6,20.9,47.7]

# %%
fig, ax = plt.subplots()
bars = ax.barh(boardid,turnover)

ax.bar_label(bars)
plt.xlabel("Market")
plt.ylabel("Turnover")
# Out:
# Text(0, 0.5, 'Turnover')
